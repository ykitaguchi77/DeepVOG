# %% [markdown]
# <a href="https://colab.research.google.com/github/ykitaguchi77/RunningDeepVOG/blob/master/Periorbit%20AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Periorbit AI** <br>
# https://github.com/uw-biomedical-ml/periorbitAI <br>
# https://linkinghub.elsevier.com/retrieve/pii/S0002939421002816

# %%
#Githubよりリポジトリをcloneする
# !git clone https://github.com/uw-biomedical-ml/periorbitAI.git
# Out:
# Cloning into 'periorbitAI'...
# remote: Enumerating objects: 92, done.
# remote: Counting objects: 100% (92/92), done.
# remote: Compressing objects: 100% (84/84), done.
# remote: Total 92 (delta 42), reused 5 (delta 1), pack-reused 0
# Unpacking objects: 100% (92/92), done.

# %%
import numpy as np
np.show_config()
# Out:
# blas_mkl_info:
#   NOT AVAILABLE
# blis_info:
#   NOT AVAILABLE
# openblas_info:
#     libraries = ['openblas', 'openblas']
#     library_dirs = ['/usr/local/lib']
#     language = c
#     define_macros = [('HAVE_CBLAS', None)]
# blas_opt_info:
#     libraries = ['openblas', 'openblas']
#     library_dirs = ['/usr/local/lib']
#     language = c
#     define_macros = [('HAVE_CBLAS', None)]
# lapack_mkl_info:
#   NOT AVAILABLE
# openblas_lapack_info:
#     libraries = ['openblas', 'openblas']
#     library_dirs = ['/usr/local/lib']
#     language = c
#     define_macros = [('HAVE_CBLAS', None)]
# lapack_opt_info:
#     libraries = ['openblas', 'openblas']
#     library_dirs = ['/usr/local/lib']
#     language = c
#     define_macros = [('HAVE_CBLAS', None)]

# %%
# !pip uninstall numpy scipy
# Out:
# Found existing installation: numpy 1.19.5
# Uninstalling numpy-1.19.5:
#   Would remove:
#     /usr/bin/f2py
#     /usr/local/bin/f2py
#     /usr/local/bin/f2py3
#     /usr/local/bin/f2py3.7
#     /usr/local/lib/python3.7/dist-packages/numpy-1.19.5.dist-info/*
#     /usr/local/lib/python3.7/dist-packages/numpy.libs/libgfortran-2e0d59d6.so.5.0.0
#     /usr/local/lib/python3.7/dist-packages/numpy.libs/libopenblasp-r0-09e95953.3.13.so
#     /usr/local/lib/python3.7/dist-packages/numpy.libs/libquadmath-2d0c479f.so.0.0.0
#     /usr/local/lib/python3.7/dist-packages/numpy.libs/libz-eb09ad1d.so.1.2.3
#     /usr/local/lib/python3.7/dist-packages/numpy/*
# Proceed (y/n)? y
#   Successfully uninstalled numpy-1.19.5
# Found existing installation: scipy 1.4.1
# Uninstalling scipy-1.4.1:
#   Would remove:
#     /usr/local/lib/python3.7/dist-packages/scipy-1.4.1.dist-info/*
#     /usr/local/lib/python3.7/dist-packages/scipy/*
# Proceed (y/n)? y
#   Successfully uninstalled scipy-1.4.1

# %%
# !pip install --no-binary :all: numpy
# Out:
# Collecting numpy
#   Downloading numpy-1.21.1.zip (10.3 MB)
#      |████████████████████████████████| 10.3 MB 28.1 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Building wheels for collected packages: numpy
#   Building wheel for numpy (PEP 517) ... done
#   Created wheel for numpy: filename=numpy-1.21.1-cp37-cp37m-linux_x86_64.whl size=13474217 sha256=9e7f0d5f5607574a93bd0697eb8626d713650e03b9f277f7f002f180a6de8f6d
#   Stored in directory: /root/.cache/pip/wheels/0b/06/e7/89f11803e6721f4a069c05d6e357c8b9153a15e1296fb95825
# Successfully built numpy
# Installing collected packages: numpy
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# yellowbrick 0.9.1 requires scipy>=1.0.0, which is not installed.
# xgboost 0.90 requires scipy, which is not installed.
# theano-pymc 1.1.2 requires scipy>=0.14, which is not installed.
# statsmodels 0.10.2 requires scipy>=0.18, which is not installed.
# sklearn-pandas 1.8.0 requires scipy>=0.14, which is not installed.
# seaborn 0.11.1 requires scipy>=1.0, which is not installed.
# scs 2.1.4 requires scipy>=0.13.2, which is not installed.
# scikit-learn 0.22.2.post1 requires scipy>=0.17.0, which is not installed.
# resampy 0.2.2 requires scipy>=0.13, which is not installed.
# qdldl 0.1.5.post0 requires scipy>=0.13.2, which is not installed.
# pymc3 3.11.2 requires scipy>=1.2.0, which is not installed.
# plotnine 0.6.0 requires scipy>=1.2.0, which is not installed.
# osqp 0.6.2.post0 requires scipy>=0.13.2, which is not installed.
# mlxtend 0.14.0 requires scipy>=0.17, which is not installed.
# missingno 0.5.0 requires scipy, which is not installed.
# matplotlib-venn 0.11.6 requires scipy, which is not installed.
# lightgbm 2.2.3 requires scipy, which is not installed.
# librosa 0.8.1 requires scipy>=1.0.0, which is not installed.
# keras 2.4.3 requires scipy>=0.14, which is not installed.
# jaxlib 0.1.69+cuda110 requires scipy, which is not installed.
# imgaug 0.2.9 requires scipy, which is not installed.
# imbalanced-learn 0.4.3 requires scipy>=0.13.3, which is not installed.
# hyperopt 0.1.2 requires scipy, which is not installed.
# gym 0.17.3 requires scipy, which is not installed.
# gensim 3.6.0 requires scipy>=0.18.1, which is not installed.
# fastai 1.0.61 requires scipy, which is not installed.
# fa2 0.3.5 requires scipy, which is not installed.
# ecos 2.0.7.post1 requires scipy>=0.9, which is not installed.
# cvxpy 1.0.31 requires scipy>=1.1.0, which is not installed.
# arviz 0.11.2 requires scipy>=0.19, which is not installed.
# albumentations 0.1.12 requires scipy, which is not installed.
# tensorflow 2.5.0 requires numpy~=1.19.2, but you have numpy 1.21.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed numpy-1.21.1

# %%
# !pip install --no-binary :all: scipy
# Out:
# Collecting scipy
#   Downloading scipy-1.7.0.tar.gz (36.1 MB)
#      |████████████████████████████████| 36.1 MB 48 kB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: numpy<1.23.0,>=1.16.5 in /usr/local/lib/python3.7/dist-packages (from scipy) (1.21.1)
# Building wheels for collected packages: scipy
#   Building wheel for scipy (PEP 517) ... done
#   Created wheel for scipy: filename=scipy-1.7.0-cp37-cp37m-linux_x86_64.whl size=56798174 sha256=b0e3c5551d76b56575e9f1ad64cc3cb9cd9d16194b27bc0933a5366676d3820f
#   Stored in directory: /root/.cache/pip/wheels/6e/af/a7/0681307791ac69c5213e12b5b371c948180573cd6b3f34d59a
# Successfully built scipy
# Installing collected packages: scipy
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed scipy-1.7.0

# %% [markdown]
# #作業ディレクトリを移動

# %%
import os
path = '/content/periorbitAI'

#作業ディレクトリをpathに移動する
os.chdir(path)

#作業ディレクトリ直下のファイルを確認
# !ls
# Out:
# example_output	net_inference.py  pspnet.py  requirements.txt
# LICENSE		photos		  README.md  run_periorbitAI.py

# %% [markdown]
# #Pythonファイルを実行する

# %%
import pandas as pd

file_name = "requirements.txt"

df = pd.read_table(file_name)
print(df)

df.iloc[:,0] = df.iloc[:,0].str.rsplit('=',1).str[0]
df.iloc[:,0] = df.iloc[:,0].str.replace('=','==')

print(df)
df.to_csv("requirements.txt", index = False)
# Out:
#     # This file may be used to create an environment using:
# 0     # $ conda create --name <env> --file <this file>
# 1                                   # platform: win-64
# 2                        aggdraw=1.3.11=py38h0f91c3a_0
# 3                                alabaster=0.7.12=py_0
# 4                                   argh=0.26.2=py38_0
# ..                                                 ...
# 172                                   yapf=0.28.0=py_0
# 173                            zeromq=4.3.1=h33f27b4_3
# 174                                    zipp=2.2.0=py_0
# 175                             zlib=1.2.11=h62dcd97_3
# 176                              zstd=1.3.7=h508b16e_0
#
# [177 rows x 1 columns]
#     # This file may be used to create an environment using:
# 0     # $ conda create --name <env> --file <this file>
# 1                                   # platform: win-64
# 2                                      aggdraw==1.3.11
# 3                                    alabaster==0.7.12
# 4                                         argh==0.26.2
# ..                                                 ...
# 172                                       yapf==0.28.0
# 173                                      zeromq==4.3.1
# 174                                        zipp==2.2.0
# 175                                       zlib==1.2.11
# 176                                        zstd==1.3.7
#
# [177 rows x 1 columns]

# %%
# !pip install -r requirements.txt
# Out:
# Collecting aggdraw==1.3.11
#   Using cached aggdraw-1.3.11-cp37-cp37m-manylinux2010_x86_64.whl (795 kB)
# Requirement already satisfied: alabaster==0.7.12 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 5)) (0.7.12)
# Collecting argh==0.26.2
#   Using cached argh-0.26.2-py2.py3-none-any.whl (30 kB)
# Collecting asn1crypto==1.3.0
#   Using cached asn1crypto-1.3.0-py2.py3-none-any.whl (103 kB)
# Collecting astroid==2.3.3
#   Using cached astroid-2.3.3-py3-none-any.whl (205 kB)
# Collecting astropy==4.2
#   Using cached astropy-4.2-cp37-cp37m-manylinux1_x86_64.whl (9.7 MB)
# Collecting atomicwrites==1.3.0
#   Using cached atomicwrites-1.3.0-py2.py3-none-any.whl (5.9 kB)
# Collecting attrs==19.3.0
#   Using cached attrs-19.3.0-py2.py3-none-any.whl (39 kB)
# Collecting autopep8==1.4.4
#   Using cached autopep8-1.4.4.tar.gz (114 kB)
# Collecting babel==2.8.0
#   Using cached Babel-2.8.0-py2.py3-none-any.whl (8.6 MB)
# Collecting backcall==0.1.0
#   Using cached backcall-0.1.0.zip (11 kB)
# Collecting bcrypt==3.1.7
#   Using cached bcrypt-3.1.7-cp34-abi3-manylinux1_x86_64.whl (56 kB)
# ERROR: Could not find a version that satisfies the requirement blas==1.0 (from versions: none)
# ERROR: No matching distribution found for blas==1.0

# %%
# !python run_periorbitAI.py /data/periorbitAI photos
# Out:
# Traceback (most recent call last):
#   File "run_periorbitAI.py", line 3, in <module>
#     import net_inference as ni
#   File "/content/periorbitAI/net_inference.py", line 7, in <module>
#     from psd_tools import PSDImage
# ModuleNotFoundError: No module named 'psd_tools'
